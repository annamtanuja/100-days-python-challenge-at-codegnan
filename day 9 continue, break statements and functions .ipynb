# %%
s= input() # srinu@123
validate_string = "fsdjhiourhgunJBUYEUDHN123456@_"
if len(s) >=8:
    # check atleast one upper case and one lower case letter
      # - first character is upper or lower
    if s[0].isupper() or s[0].islower():
        for i in range(1, len(s)):
           if s[i] not in validate_string:
               print(f"Invalid username because character {s[i]}")
               break
        else:
           print("valid_string")
      
      # - special characters ('_','@')
      #- it contains digits
    else:    
      print("username not valid because first character is not upper or not lower")
else:
      print("username not valid because first character is not upper or not lower")
# Out:
#  srinu@123
# valid_string

# %%
for i in range(1,6):
    if i == 3:
        continue
    print(i)
else:
    print("program done")
# Out:
# 1
# 2
# 4
# 5
# program done

# %%
for i in range(1,6):
    if i == 3:
        break
    print(i)
else:
    print("program done")
# Out:
# 1
# 2

# %%
#sum of two numbers
n1=int(input("enter first number: "))
n2=int(input("enter second number: "))
sum=n1+n2
print(f"sum of two numbers {n1} and {n2} is",sum )
# Out:
# enter first number:  4
# enter second number:  5
# sum of two numbers 4 and 5 is 9

# %%
# sum of two numbers using functions
def addition_of_two_numbers(a,b) :
    s=a+b 
    return s
result = addition_of_two_numbers(10,20)
print(result)
# Out:
# 30

# %% [markdown]
#  ### basic calculator using functions

# %%
def add(a,b):
    r=a+b
    return r
def sub(a,b):
    s=a-b
    return s
def mul(a,b):
    t=a*b
    return t
def div(a,b):
    if b==0 :
        return "zero division not possible"
    u=a/b
    return u
if __name__ == "__main__" :
    print("welcome to small level calculator") 
r=add(20,10)
print(r)
s=sub(20,10)
print(s)
t=mul(20,10)
print(t)
u=div(20,10)
print(u)
# Out:
# welcome to small level calculator
# 30
# 10
# 200
# 2.0

# %%
def addition(a,b):
    return a+b
def subtraction(a,b):   
    return a-b
def multiple(a,b):   
    return a*b
def division(a,b):
    if b==0:
        return "Zero division not possible"
    return a/b
if __name__ == "__main__":
    print("Welcome to small level calculator")
    n1 = int(input("Enter number 1:"))
    n2 = int(input("Enter number 2:"))
    print("1. addition /n 2. subtraction /n 3. multiple /n 4. division")
    choice = int(input("Enter your choice:"))
    if choice == 1:
        print("addition of two numbers s:", addition(n1,n2))
    elif choice == 2:
        print("subtraction of two numbers s:", subtraction(n1,n2))
    elif choice == 3:
        print("multiple of two numbers s:", multiple(n1,n2))
    elif choice == 4:
        print("division of two numbers s:", division(n1,n2))
    else :
        print("please select correct operation")
# Out:
# Welcome to small level calculator
# Enter number 1: 46
# Enter number 2: 78
# 1. addition /n 2. subtraction /n 3. multiple /n 4. division
# Enter your choice: 4
# division of two numbers s: 0.5897435897435898
